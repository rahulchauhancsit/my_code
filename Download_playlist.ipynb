# %%
from pytube import Playlist
from pytube import YouTube

play_list = []

#Accessing the Playlist

playlist = Playlist("https://www.youtube.com/watch?v=FLuqwQgSBDw&list=PLupD_xFct8mFDeCqoUAWZpUddeqmT28_L")

#Checking the number of videos in the playlist

print('Number of videos in playlist: %s' % len(playlist.video_urls))

#Parsing through the playlist and appending the video urls in play_list
for video_url in playlist.video_urls:
    print(video_url)
    play_list.append(video_url)

#Looping through the list
for i in play_list:
    try:
        yt = YouTube(i)
        print('Downloading Link: ' + i)
        print('Downloading video: ' + yt.streams[0].title)
    except:
        print("Connection Error")

#filters out all the files with "mp4" extension
    stream = yt.streams.filter(res="720p").first()
    stream.download("Playlist_Videos/")
print('Task Completed!')
# Out:
# Number of videos in playlist: 15
# https://www.youtube.com/watch?v=FLuqwQgSBDw
# https://www.youtube.com/watch?v=lusJoN63jFY
# https://www.youtube.com/watch?v=b7JuBsswDlo
# https://www.youtube.com/watch?v=CfhvcF4kVfE
# https://www.youtube.com/watch?v=MEvYZiz-mK4
# https://www.youtube.com/watch?v=11BFX7Ygtyo
# https://www.youtube.com/watch?v=57_Q1GGFs90
# https://www.youtube.com/watch?v=OmLMRgiO2qs
# https://www.youtube.com/watch?v=RX1YW7DvK20
# https://www.youtube.com/watch?v=kecBYc5N8dc
# https://www.youtube.com/watch?v=BVmL3VQCmEM
# https://www.youtube.com/watch?v=a2t2EQd5SC4
# https://www.youtube.com/watch?v=llbsNJC0kbQ
# https://www.youtube.com/watch?v=Kx85fmXLmx4
# https://www.youtube.com/watch?v=hCBr43Wv_Es
# Downloading Link: https://www.youtube.com/watch?v=FLuqwQgSBDw
# Downloading video: Iris Dataset EDA Lecture1@ Applied AI Course
# Downloading Link: https://www.youtube.com/watch?v=lusJoN63jFY
# Downloading video: 3d scatter plot EDA Lecture 2@ Applied AI Course
# Downloading Link: https://www.youtube.com/watch?v=b7JuBsswDlo
# Downloading video: Pair plot EDA Lecture 3 @Applied AI Course
# Downloading Link: https://www.youtube.com/watch?v=CfhvcF4kVfE
# Downloading video: Limitations of Pair Plots EDA Lecture 4 @Applied AI Course
# Downloading Link: https://www.youtube.com/watch?v=MEvYZiz-mK4
# Downloading video: Univariate analysis using PDF EDA Lecture 6@ Applied AI Course
# Downloading Link: https://www.youtube.com/watch?v=11BFX7Ygtyo
# Downloading video: Mean,variance,std dev EDA Lecture 8@ Applied AI Course
# Downloading Link: https://www.youtube.com/watch?v=57_Q1GGFs90
# Downloading video: Median EDA Lecture 9 @Applied AI Course
# Downloading Link: https://www.youtube.com/watch?v=OmLMRgiO2qs
# Downloading video: Meadian,Percentiles,Quantiles  EDA Lecture 10@Applied AI Course
# Downloading Link: https://www.youtube.com/watch?v=RX1YW7DvK20
# Downloading video: Box-plot with whiskers EDA Lecture 11@Applied AI Course
# Downloading Link: https://www.youtube.com/watch?v=kecBYc5N8dc
# Downloading video: Violin plots EDA Lecture 12@Applied AI Course
# Downloading Link: https://www.youtube.com/watch?v=BVmL3VQCmEM
# Downloading video: Univariate, Bivariate and Multivariate analysis EDA Lecture 13@Applied AI Course
# Downloading Link: https://www.youtube.com/watch?v=a2t2EQd5SC4
# Downloading video: Multivariate probability density, contour plot EDA Lecture 14@Applied AI Course
# Downloading Link: https://www.youtube.com/watch?v=llbsNJC0kbQ
# Downloading video: Assignment:  Data Analysis on Haberman Dataset EDA Lecture 15@Applied AI Course
# Downloading Link: https://www.youtube.com/watch?v=Kx85fmXLmx4
# Downloading video: IQR(Inter Quartile Range) and MAD(Median Absolute Deviation) EDA Lecture 11@ Applied AI Course
# Downloading Link: https://www.youtube.com/watch?v=hCBr43Wv_Es
# Downloading video: Cumulative Distribution Function(CDF): EDA Lecture 7 @ Applied AI Course
# Task Completed!
